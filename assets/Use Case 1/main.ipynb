# %%
# %pip install pydantic_settings langchain langchain-core langchain-google-genai langchain-qdrant fastembed langchain-community qdrant-client langgraph
# Out:
# I0000 00:00:1753944379.290108  812510 fork_posix.cc:71] Other threads are currently calling into gRPC, skipping fork() handlers
# Requirement already satisfied: pydantic_settings in /opt/homebrew/anaconda3/lib/python3.12/site-packages (2.9.1)
# Requirement already satisfied: langchain in /opt/homebrew/anaconda3/lib/python3.12/site-packages (0.3.25)
# Requirement already satisfied: langchain-core in /opt/homebrew/anaconda3/lib/python3.12/site-packages (0.3.72)
# Requirement already satisfied: langchain-google-genai in /opt/homebrew/anaconda3/lib/python3.12/site-packages (2.1.8)
# Requirement already satisfied: langchain-qdrant in /opt/homebrew/anaconda3/lib/python3.12/site-packages (0.2.0)
# Requirement already satisfied: fastembed in /opt/homebrew/anaconda3/lib/python3.12/site-packages (0.7.1)
# Requirement already satisfied: langchain-community in /opt/homebrew/anaconda3/lib/python3.12/site-packages (0.3.24)
# Requirement already satisfied: qdrant-client in /opt/homebrew/anaconda3/lib/python3.12/site-packages (1.15.0)
# Requirement already satisfied: langgraph in /opt/homebrew/anaconda3/lib/python3.12/site-packages (0.6.2)
# Requirement already satisfied: pydantic>=2.7.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pydantic_settings) (2.11.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pydantic_settings) (1.1.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pydantic_settings) (0.4.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langchain) (0.3.45)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langchain) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langchain-core) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langchain-core) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langchain-core) (4.13.2)
# Requirement already satisfied: packaging>=23.2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langchain-core) (24.2)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-ai-generativelanguage<0.7.0,>=0.6.18 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langchain-google-genai) (0.6.18)
# Requirement already satisfied: huggingface-hub<1.0,>=0.20 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from fastembed) (0.31.4)
# Requirement already satisfied: loguru<0.8.0,>=0.7.2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from fastembed) (0.7.3)
# Requirement already satisfied: mmh3<6.0.0,>=4.1.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from fastembed) (5.1.0)
# Requirement already satisfied: numpy>=1.26 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from fastembed) (2.2.6)
# Requirement already satisfied: onnxruntime!=1.20.0,>=1.17.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from fastembed) (1.22.0)
# Requirement already satisfied: pillow<12.0.0,>=10.3.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from fastembed) (11.2.1)
# Requirement already satisfied: py-rust-stemmers<0.2.0,>=0.1.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from fastembed) (0.1.5)
# Requirement already satisfied: tokenizers<1.0,>=0.15 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from fastembed) (0.21.1)
# Requirement already satisfied: tqdm<5.0,>=4.66 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from fastembed) (4.67.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langchain-community) (3.11.18)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: grpcio>=1.41.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from qdrant-client) (1.74.0)
# Requirement already satisfied: httpx>=0.20.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpx[http2]>=0.20.0->qdrant-client) (0.28.1)
# Requirement already satisfied: portalocker<4.0,>=2.7.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from qdrant-client) (3.2.0)
# Requirement already satisfied: protobuf>=3.20.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from qdrant-client) (6.31.1)
# Requirement already satisfied: urllib3<3,>=1.26.14 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from qdrant-client) (2.4.0)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.1.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langgraph) (2.1.1)
# Requirement already satisfied: langgraph-prebuilt<0.7.0,>=0.6.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langgraph) (0.6.2)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langgraph) (0.2.0)
# Requirement already satisfied: xxhash>=3.5.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langgraph) (3.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2.25.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2.40.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.26.1)
# Requirement already satisfied: anyio in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (4.9.0)
# Requirement already satisfied: certifi in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (1.0.9)
# Requirement already satisfied: idna in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (3.10)
# Requirement already satisfied: h11>=0.16 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (0.16.0)
# Requirement already satisfied: h2<5,>=3 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from httpx[http2]>=0.20.0->qdrant-client) (4.2.0)
# Requirement already satisfied: filelock in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.20->fastembed) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.20->fastembed) (2025.3.2)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langgraph-checkpoint<3.0.0,>=2.1.0->langgraph) (1.10.0)
# Requirement already satisfied: orjson>=3.10.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langgraph-sdk<0.3.0,>=0.2.0->langgraph) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: coloredlogs in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from onnxruntime!=1.20.0,>=1.17.0->fastembed) (15.0.1)
# Requirement already satisfied: flatbuffers in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from onnxruntime!=1.20.0,>=1.17.0->fastembed) (25.2.10)
# Requirement already satisfied: sympy in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from onnxruntime!=1.20.0,>=1.17.0->fastembed) (1.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pydantic>=2.7.0->pydantic_settings) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pydantic>=2.7.0->pydantic_settings) (2.33.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.70.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.74.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (4.9.1)
# Requirement already satisfied: hyperframe<7,>=6.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client) (4.1.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from anyio->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from coloredlogs->onnxruntime!=1.20.0,>=1.17.0->fastembed) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from sympy->onnxruntime!=1.20.0,>=1.17.0->fastembed) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pydantic_settings import BaseSettings, SettingsConfigDict

class Settings(BaseSettings):
    GOOGLE_API_KEY: str
    model_config = SettingsConfigDict(env_file=".env")

env = Settings()

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

embeddings_2 = GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-001", google_api_key=env.GOOGLE_API_KEY)

# %%
from qdrant_client.http.models import Distance

collection_name = "list_doctors"
dimension = 3072
distance = Distance.COSINE

# %%
import json

with open("doctors_final.json", "r") as f:
    list_doctkers = json.load(f)

print(list_doctkers[0])
# Out:
# {'id': '5eae0017-40dd-4961-869f-79d9e45d87f2', 'name': 'Adventia Emilia Krysna Sipi Seda, M.M., M.Psi., Psikolog', 'specialization_name': 'Psikologi', 'specialization_name_en': 'Psychology', 'sub_specialization_name': 'Psikolog', 'sub_specialization_name_en': 'Psychologist', 'hospital_name': 'Siloam Hospitals Yogyakarta'}

# %%
from qdrant_client import QdrantClient

client = QdrantClient(":memory:")

# %%
from qdrant_client.http.models import VectorParams

if(client.collection_exists(collection_name=collection_name) == False):
    client.create_collection(
        collection_name=collection_name,
        vectors_config=VectorParams(size=dimension, distance=distance),
    )

# %%
import time
import uuid
from qdrant_client.models import PointStruct
from google.api_core.exceptions import ResourceExhausted

MAX_RETRY = 5
RETRY_DELAY_SECONDS = 2 
collection_name = "list_doctors"

def embed_with_retry(text, max_retry=MAX_RETRY):
    for attempt in range(1, max_retry + 1):
        try:
            return embeddings_2.embed_query(text)
        except ResourceExhausted as e:
            print(f"[Attempt {attempt}] Rate limit hit. Retrying in {RETRY_DELAY_SECONDS * attempt} seconds...")
            time.sleep(RETRY_DELAY_SECONDS * attempt)
        except Exception as e:
            print(f"[Attempt {attempt}] Failed to embed: {e}")
            raise e
    raise RuntimeError("Max retries reached. Embedding failed.")

for i, row in enumerate(list_doctkers, start=1):
    try:
        text = f"Doctor: {row['name']}, specialization_name: {row['specialization_name_en']}, location: {row['hospital_name']}"
        emb = embed_with_retry(text)
        
        point = PointStruct(
            id=str(uuid.uuid4()),
            vector=emb,
            payload={
                "page_content": text,
                "metadata": {
                    "id": row['id'],
                    "name": row['name'],
                    "specialization_name": row['specialization_name_en'],
                    "sub_specialization_name": row.get("sub_specialization_name_en", ""),
                    "hospital_name": row["hospital_name"]
                },
            },
        )
        client.upsert(
            collection_name=collection_name,
            points=[point]
        )
        print(f"[{i}] Successfully upserted: {text}")

    except Exception as e:
        print(f"[{i}] Failed processing doctor '{row.get('name', '-')}' due to error: {e}")
        continue
# Out:
# [1] Successfully upserted: Doctor: Adventia Emilia Krysna Sipi Seda, M.M., M.Psi., Psikolog, specialization_name: Psychology, location: Siloam Hospitals Yogyakarta
# [2] Successfully upserted: Doctor: Dokter Umum Siloam Yogyakarta, specialization_name: General Practitioner, location: Siloam Hospitals Yogyakarta
# [3] Successfully upserted: Doctor: dr. Andrean Jefrian Manihuruk, specialization_name: General Practitioner, location: Siloam Hospitals Yogyakarta
# [4] Successfully upserted: Doctor: dr. Anggoro Budi Hartopo, M.Sc., Ph.D., SpPD., SpJP (K), specialization_name: Cardiology (Heart), location: Siloam Hospitals Yogyakarta
# [5] Successfully upserted: Doctor: dr. Antonius Arif Kusuma, SpB, specialization_name: General Surgery, location: Siloam Hospitals Yogyakarta
# [6] Successfully upserted: Doctor: dr. Antonius Sri Widayanto, SpOG, specialization_name: Obstetrics and Gynecology, location: Siloam Hospitals Yogyakarta
# [7] Successfully upserted: Doctor: dr. Arvin Manuel Wulur, SpKFR, AIFO-K, specialization_name: Medical Rehabilitation, location: Siloam Hospitals Yogyakarta
# [8] Successfully upserted: Doctor: dr. Azmi Farah Fairuzya, Sp.N, AIFO-K, specialization_name: Neurology (Brain and Nervous System), location: Siloam Hospitals Yogyakarta
# [9] Successfully upserted: Doctor: dr. Catharina Triwikatmani, M. Kes, SpPD-KGEH, specialization_name: Internal Medicine, location: Siloam Hospitals Yogyakarta
# [10] Successfully upserted: Doctor: dr. Danny Wiguna, SpOG, specialization_name: Obstetrics and Gynecology, location: Siloam Hospitals Yogyakarta
# [11] Successfully upserted: Doctor: dr. Dina Putri Chandra, SpKK, specialization_name: Dermatology (Skin), location: Siloam Hospitals Yogyakarta
# [12] Successfully upserted: Doctor: dr. Dirgantara Fathurrizki Harfanie, specialization_name: General Practitioner, location: Siloam Hospitals Yogyakarta
# [13] Successfully upserted: Doctor: Dr. dr. Prahara Yuri, SpU (K), FICS, specialization_name: Urology, location: Siloam Hospitals Yogyakarta
# [14] Successfully upserted: Doctor: Dr. dr. Raden Ludhang Pradipta Rizki, M.Biotech, Sp.MK (K), specialization_name: Medical Laboratory, location: Siloam Hospitals Yogyakarta
# [15] Successfully upserted: Doctor: dr. Dyah Ayu Kartika Dewanti, MSc, SpTHT-KL (K), specialization_name: Otorhinolaryngology (ENT), location: Siloam Hospitals Yogyakarta
# [16] Successfully upserted: Doctor: dr. Eduardus Raditya Kusuma Putra, SpOG, FISQua, specialization_name: Obstetrics and Gynecology, location: Siloam Hospitals Yogyakarta
# [17] Successfully upserted: Doctor: dr. Fadlila Fitriani, M.Sc, Sp.PD, specialization_name: Internal Medicine, location: Siloam Hospitals Yogyakarta
# [18] Successfully upserted: Doctor: dr. Ferareza Urbaningrum, specialization_name: General Practitioner, location: Siloam Hospitals Yogyakarta
# [19] Successfully upserted: Doctor: drg. Adi Subekti Putra, SpBMM, SubSp.TMF-TMD(K), specialization_name: Dentistry, location: Siloam Hospitals Yogyakarta
# [20] Successfully upserted: Doctor: drg. Bintang Charisma Putri Lolobua, MDSc, specialization_name: Dentistry, location: Siloam Hospitals Yogyakarta
#
SpTHT-KL, specialization_name: Otorhinolaryngology (ENT), location: Siloam Hospitals Denpasar
# [105] Successfully upserted: Doctor: dr. A. Abadi, SpOG-KFER, specialization_name: Obstetrics and Gynecology, location: Siloam Sriwijaya Palembang
# [106] Successfully upserted: Doctor: dr. A.A Bagus Indra Permadi, SpOG, specialization_name: Obstetrics and Gynecology, location: Siloam Hospitals Denpasar
# [107] Successfully upserted: Doctor: Dra. Astrid Regina Sapii Wiratna, specialization_name: Psychology, location: Siloam Hospitals Surabaya
# [108] Successfully upserted: Doctor: dr. Abdul Halim Raynaldo, SpJP (K), specialization_name: Cardiology (Heart), location: Siloam Hospitals Medan
# [109] Successfully upserted: Doctor: dr. Abdul Rahman, M.Kes, SpTHT, specialization_name: Otorhinolaryngology (ENT), location: Siloam Hospitals Bekasi Sepanjang Jaya
# [110] Successfully upserted: Doctor: dr. Achmad Fikry, SpPD, K-GH, specialization_name: Internal Medicine, location: Siloam Hospitals Makassar
# [111] Successfully upserted: Doctor: dr. Achmad Taufan, SpOG, specialization_name: Obstetrics and Gynecology, location: Siloam Hospitals Lubuk Linggau
# [112] Successfully upserted: Doctor: dr. Achmad Yusri, SpJP, specialization_name: Cardiology (Heart), location: Siloam Hospitals Balikpapan
# [113] Successfully upserted: Doctor: dr. Achmad Yusuf, SpKK, specialization_name: Dermatology (Skin), location: Siloam Hospitals Surabaya
# [114] Successfully upserted: Doctor: dr. Achnes Pangaribuan, M.Biomed, SpPD, specialization_name: Internal Medicine, location: Siloam Hospitals Bekasi Timur
# [115] Successfully upserted: Doctor: dr. Ade Chandra, SpB, specialization_name: General Surgery, location: Siloam Hospitals Denpasar
# [116] Successfully upserted: Doctor: dr. Adela Stephani Sampouw, specialization_name: General Practitioner, location: Siloam Hospitals Surabaya
# [117] Successfully upserted: Doctor: dr. Adelgrit Trisia, SpA, specialization_name: Pediatrics, location: Siloam Hospitals Palangkaraya
# [118] Successfully upserted: Doctor: dr. Ade Rahmatdianto, specialization_name: General Practitioner, location: Siloam Hospitals Surabaya
# [119] Successfully upserted: Doctor: dr. Ade Tan Reza, Sp.B. SubSp.BD(K), specialization_name: Digestive Surgery, location: Siloam Hospitals Jambi
# [120] Successfully upserted: Doctor: dr. Adhita Kartyanto, SpPD, specialization_name: Internal Medicine, location: RSU Syubbanul Wathon
# [121] Successfully upserted: Doctor: dr. Adhitya Indrapraja, SpOG, M.Kes, specialization_name: Obstetrics and Gynecology, location: Siloam Hospitals Lippo Cikarang
# [122] Successfully upserted: Doctor: dr. Adi Agung Anantawijaya Daryago, SpDV, specialization_name: Dermatology (Skin), location: Siloam Hospitals Bekasi Timur
# [123] Successfully upserted: Doctor: dr. Adianto Dwi Prasetio Z, SpP, specialization_name: Pulmonology (Lung), location: RS Jantung Diagram Cinere
# [124] Successfully upserted: Doctor: dr. Adianto Jaya Nagara Iskandar Winata Tjea, SpDVE, specialization_name: Dermatology (Skin), location: Siloam Hospitals Balikpapan
# [125] Successfully upserted: Doctor: dr. Adi Aryanto, SpOT (K), specialization_name: Orthopaedics (Bone), location: Siloam Hospitals
SpOG, specialization_name: Obstetrics and Gynecology, location: Siloam Hospitals Semarang
# [436] Successfully upserted: Doctor: dr. Cornellia Agatha, specialization_name: General Practitioner, location: Siloam Sriwijaya Palembang
# [437] Successfully upserted: Doctor: dr. Cosmas Hascaryanto Kunhermawan, SpM, specialization_name: Ophthalmology (Eyes), location: Siloam Hospitals Jember
# [438] Successfully upserted: Doctor: dr. Cynthia Elvira Sari Siahaan, specialization_name: General Practitioner, location: Siloam Hospitals Sentosa
# [439] Successfully upserted: Doctor: dr. Cynthia Ganda, specialization_name: General Practitioner, location: Siloam Hospitals Medan
# [440] Successfully upserted: Doctor: dr. Cynthia Jodjana, SpA, specialization_name: Pediatrics, location: Siloam Hospitals Surabaya
# [441] Successfully upserted: Doctor: dr. Cynthia Tanaka, SpB, specialization_name: General Surgery, location: Siloam Hospitals Jember
# [442] Successfully upserted: Doctor: dr. Dachrial Daud, SpOG, specialization_name: Obstetrics and Gynecology, location: Siloam Hospitals Lippo Village
# [443] Successfully upserted: Doctor: dr. Dadang Rona Sasetyo, SpOT (K), specialization_name: Orthopaedics (Bone), location: Siloam Hospitals ASRI
# [444] Successfully upserted: Doctor: dr. Dahlia, Sp.OG, specialization_name: Obstetrics and Gynecology, location: Siloam Hospitals Mataram
# [445] Successfully upserted: Doctor: dr. Damayanti Eka Fransiska Malau, SpOG, specialization_name: Obstetrics and Gynecology, location: Siloam Hospitals Jambi
# [446] Successfully upserted: Doctor: dr. Damba Dwisepto Aulia Sakti, SpJP (K), specialization_name: Cardiology (Heart), location: Siloam Hospitals Kebon Jeruk

# %%
from langchain_qdrant import QdrantVectorStore
def get_retriever():

    vector_store = QdrantVectorStore(
        client=client,
        collection_name=collection_name,
        embedding=embeddings_2,
    )
    
    return vector_store.as_retriever()

# %%
from langchain_core.tools import tool
from typing import Annotated, List

@tool
def search_match_doctor(query: Annotated[str, "Search query must contain keywords related to doctor name, specialization, or hospital location"]) -> List[str]:
    """Search for doctors by name, specialization, sub-specialization, or hospital affiliation."""
    retriever = get_retriever()
    results = retriever.invoke(query)
    return [result.page_content for result in results]

# %%
search_match_doctor("saya sakit kepala dan saya berasal dari jogja tolong berikan saya rekomendasi dokternya")
# Out:
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/langchain_google_genai/embeddings.py:243, in GoogleGenerativeAIEmbeddings.embed_documents(self, texts, batch_size, task_type, titles, output_dimensionality)
#     242 try:
# --> 243     result = self.client.batch_embed_contents(
#     244         BatchEmbedContentsRequest(requests=requests, model=self.model)
#     245     )
#     246 except Exception as e:
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py:1437, in GenerativeServiceClient.batch_embed_contents(self, request, model, requests, retry, timeout, metadata)
#    1436 # Send the request.
# -> 1437 response = rpc(
#    1438     request,
#    1439     retry=retry,
#    1440     timeout=timeout,
#    1441     metadata=metadata,
#    1442 )
#    1444 # Done; return the response.
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/google/api_core/retry/retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/google/api_core/retry/retry_unary.py:156, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     154 except Exception as exc:
#     155     # defer to shared logic for handling errors
# --> 156     next_sleep = _retry_error_helper(
#     157         exc,
#     158         deadline,
#     159         sleep_iter,
#     160         error_list,
#     161         predicate,
#     162         on_error,
#     163         exception_factory,
#     164         timeout,
#     165     )
#     166     # if exception not raised, sleep before next attempt
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/google/api_core/retry/retry_base.py:214, in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     209     final_exc, source_exc = exc_factory_fn(
#     210         error_list,
#     211         RetryFailureReason.NON_RETRYABLE_ERROR,
#     212         original_timeout,
#     213     )
# --> 214     raise final_exc from source_exc
#     215 if on_error_fn is not None:
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/google/api_core/retry/retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     146 try:
# --> 147     result = target()
#     148     if inspect.isawaitable(result):
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/google/api_core/timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/google/api_core/grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# ResourceExhausted: 429 Resource has been exhausted (e.g. check quota).
#
# The above exception was the direct cause of the following exception:
#
# GoogleGenerativeAIError                   Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 search_match_doctor("saya sakit kepala dan saya berasal dari jogja tolong berikan saya rekomendasi dokternya")
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/langchain_core/_api/deprecation.py:189, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     187     warned = True
#     188     emit_warning()
# --> 189 return wrapped(*args, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/langchain_core/tools/base.py:1013, in BaseTool.__call__(self, tool_input, callbacks)
#    1002 @deprecated("0.1.47", alternative="invoke", removal="1.0")
#    1003 def __call__(self, tool_input: str, callbacks: Callbacks = None) -> str:
#    1004     """Make tool callable (deprecated).
#    1005
#    1006     Args:
#    (...)
#    1011         The tool's output.
#    1012     """
# -> 1013     return self.run(tool_input, callbacks=callbacks)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/langchain_core/tools/base.py:883, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     881 if error_to_raise:
#     882     run_manager.on_tool_error(error_to_raise)
# --> 883     raise error_to_raise
#     884 output = _format_output(content, artifact, tool_call_id, self.name, status)
#     885 run_manager.on_tool_end(output, color=color, name=self.name, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/langchain_core/tools/base.py:852, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     850     if config_param := _get_runnable_config_param(self._run):
#     851         tool_kwargs |= {config_param: config}
# --> 852     response = context.run(self._run, *tool_args, **tool_kwargs)
#     853 if self.response_format == "content_and_artifact":
#     854     if not isinstance(response, tuple) or len(response) != 2:
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/langchain_core/tools/structured.py:93, in StructuredTool._run(self, config, run_manager, *args, **kwargs)
#      91     if config_param := _get_runnable_config_param(self.func):
#      92         kwargs[config_param] = config
# ---> 93     return self.func(*args, **kwargs)
#      94 msg = "StructuredTool does not support sync invocation."
#      95 raise NotImplementedError(msg)
#
# Cell In[40], line 7, in search_match_doctor(query)
#       4 @tool
#       5 def search_match_doctor(query: Annotated[str, "Search query must contain keywords related to doctor name, specialization, or hospital location"]) -> List[str]:
#       6     """Search for doctors by name, specialization, sub-specialization, or hospital affiliation."""
# ----> 7     retriever = get_retriever()
#       8     results = retriever.invoke(query)
#       9     return [result.page_content for result in results]
#
# Cell In[38], line 4, in get_retriever()
#       2 def get_retriever():
# ----> 4     vector_store = QdrantVectorStore(
#       5         client=client,
#       6         collection_name=collection_name,
#       7         embedding=embeddings_2,
#       8     )
#      10     return vector_store.as_retriever()
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/langchain_qdrant/qdrant.py:213, in QdrantVectorStore.__init__(self, client, collection_name, embedding, retrieval_mode, vector_name, content_payload_key, metadata_payload_key, distance, sparse_embedding, sparse_vector_name, validate_embeddings, validate_collection_config)
#     210     self._validate_embeddings(retrieval_mode, embedding, sparse_embedding)
#     212 if validate_collection_config:
# --> 213     self._validate_collection_config(
#     214         client,
#     215         collection_name,
#     216         retrieval_mode,
#     217         vector_name,
#     218         sparse_vector_name,
#     219         distance,
#     220         embedding,
#     221     )
#     223 self._client = client
#     224 self.collection_name = collection_name
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/langchain_qdrant/qdrant.py:1050, in QdrantVectorStore._validate_collection_config(cls, client, collection_name, retrieval_mode, vector_name, sparse_vector_name, distance, embedding)
#    1038 @classmethod
#    1039 def _validate_collection_config(
#    1040     cls: Type[QdrantVectorStore],
#    (...)
#    1047     embedding: Optional[Embeddings],
#    1048 ) -> None:
#    1049     if retrieval_mode == RetrievalMode.DENSE:
# -> 1050         cls._validate_collection_for_dense(
#    1051             client, collection_name, vector_name, distance, embedding
#    1052         )
#    1054     elif retrieval_mode == RetrievalMode.SPARSE:
#    1055         cls._validate_collection_for_sparse(
#    1056             client, collection_name, sparse_vector_name
#    1057         )
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/langchain_qdrant/qdrant.py:1109, in QdrantVectorStore._validate_collection_for_dense(cls, client, collection_name, vector_name, distance, dense_embeddings)
#    1106 assert vector_config is not None, "VectorParams is None"
#    1108 if isinstance(dense_embeddings, Embeddings):
# -> 1109     vector_size = len(dense_embeddings.embed_documents(["dummy_text"])[0])
#    1110 elif isinstance(dense_embeddings, list):
#    1111     vector_size = len(dense_embeddings)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/langchain_google_genai/embeddings.py:247, in GoogleGenerativeAIEmbeddings.embed_documents(self, texts, batch_size, task_type, titles, output_dimensionality)
#     243         result = self.client.batch_embed_contents(
#     244             BatchEmbedContentsRequest(requests=requests, model=self.model)
#     245         )
#     246     except Exception as e:
# --> 247         raise GoogleGenerativeAIError(f"Error embedding content: {e}") from e
#     248     embeddings.extend([list(e.values) for e in result.embeddings])
#     249 return embeddings
#
# GoogleGenerativeAIError: Error embedding content: 429 Resource has been exhausted (e.g. check quota).

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate

llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",
    api_key=env.GOOGLE_API_KEY,
)

prompt = ChatPromptTemplate.from_messages([
    ("system", """
You are a domain expert assistant for Siloam Hospitals.

Your job is to extract **one concise keyword** from the user's question to help match them with the most suitable **doctor** based on either:
- medical specialization (e.g., cardiology, dermatology, pediatrician), or
- user location (e.g., Jakarta, Surabaya, BSD, etc.).

Instructions:
- Only return **one keyword in English** — either a specialization or location.
- If the user's question includes a suitable keyword, return it as is.
- Do **not** add any explanations, greetings, or extra text — just the keyword.
- If no relevant keyword is found, return an empty string ("").

This keyword will be used to search in the Siloam doctor directory.
"""),
    ("human", "{question}"),
])

chain = prompt | llm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 6
#       1 from langchain_google_genai import ChatGoogleGenerativeAI
#       2 from langchain_core.prompts import ChatPromptTemplate
#       4 llm = ChatGoogleGenerativeAI(
#       5     model="gemini-2.0-flash",
# ----> 6     api_key=env.GOOGLE_API_KEY,
#       7 )
#       9 prompt = ChatPromptTemplate.from_messages([
#      10     ("system", """
#      11 You are a domain expert assistant for Siloam Hospitals.
#    (...)
#      25     ("human", "{question}"),
#      26 ])
#      28 chain = prompt | llm
#
# NameError: name 'env' is not defined

# %%
chain.invoke({"question": "Saya mau cek gula darah di siloam bali, dokter yang cocok siapa ya ?"})

# %%
from langgraph.graph import START, StateGraph
from typing_extensions import List, TypedDict
class State(TypedDict):
    question: str
    context: List[str]
    search: str
    answer: str

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate

def get_context(state: State):
    prompt = ChatPromptTemplate.from_messages(
        [
            ("system", """
                You are a domain expert in healthcare services at Siloam Hospitals.
                Your task is to extract a **single relevant keyword** from the user's question to help match them with the most appropriate **doctor** based on specialization and/or location.

                Guidelines:
                - Only return **one keyword in English**, based on the user’s question.
                - If the question already contains a suitable keyword (e.g., a specialization or city), return it as is.
                - Prioritize medical specialties (e.g., cardiology, pediatrician) or geographic indicators (e.g., Jakarta, Surabaya).
                - Do **not** include any explanatory text or additional information.
                - Ignore general health questions that don’t indicate a clear intent to find a doctor.

                This keyword will be used to query the vector database for doctor matching.
                """),
                ("human", "{question}")
        ]
    )
    chain = prompt | llm
    result = chain.invoke({"question": state["question"]})
    return {"search": result.content}

# %%
def retrieve(state: State):
    retrieved_docs = search_match_doctor(state["search"])
    return {"context": retrieved_docs}

# %%
def generate(state: State):
    prompt = ChatPromptTemplate.from_messages(
        [
            ("system", """
                You are an assistant that provides information about Medical Check-Up (MCU) packages at Siloam hospitals.
                You will generate a response based on the context provided.
                The response should be concise and relevant to the question asked.
                package list knowledge: 
                {context}
                If the context is empty, you can provide a general response about MCU packages.
                Please always include related packages in your response.
            """),
            ("human", "{question}"),
        ]
    )
    chain = prompt | llm
    result = chain.invoke({"question": state["question"], "context": state["context"]})
    return {"answer": result.content}

# %%
graph_builder = StateGraph(State).add_sequence([get_context, retrieve, generate])
graph_builder.add_edge(START, "get_context")
graph = graph_builder.compile()

# %%
response = graph.invoke({
	"question": "Saya mau cek gula darah di siloam, ada paket apa aja ya ?",
	"context": [],
	"search": "",
	"answer": ""
})
print(response["answer"])
